# %%
import pickle
import pandas as pd
import json

# %%
try:
    with open('result_20240825_114913.json', 'r') as json_file:
        data = json.load(json_file)
except json.JSONDecodeError:
    print("Error: The JSON file is empty or contains invalid JSON.")
except FileNotFoundError:
    print("Error: The file was not found.")

# %%
data["Blocks"][71]['Text']
# Out:
# 'ABC HOSPITAL'

# %%
for index,item in enumerate(data["Blocks"], start =0):
    print(f"Item {index}:")
    if 'Text' in item:
        print(item['Text'])
# Out:
# Item 0:
# Item 1:
# HOW TO READ YOUR
# Item 2:
# Below is a sample Explanation of Benefits (EOB) Statement. This
# Item 3:
# is the information you will receive after your benefits claim has
# Item 4:
# Explanation of
# Item 5:
# been processed. In order to understand this example, match the
# Item 6:
# field number on the EOB to the corresponding number shown in
# Item 7:
# Benefits Statement
# Item 8:
# the following narrative.
# Item 9:
# HIGHMARK.
# Item 10:
# BLUE SHIELD
# Item 11:
# Explanation of Benefits
# Item 12:
# Need Help? Call 1-800-241-5704
# Item 13:
# 1800 CENTER STREET
# Item 14:
# CAMP HILL PA 17089
# Item 15:
# THIS IS NOT A BILL
# Item 16:
# CONTRACT HOLDER NAME: JOHN DOE
# Item 17:
# 1
# Item 18:
# EXPLANATION AT A GLANCE
# Item 19:
# MEMBER ID: ABC123451284
# Item 20:
# 2
# Item 21:
# DATES OF SERVICE: 12/18/03-12/20/03
# Item 22:
# 5
# Item 23:
# GROUP NAME: XYZ COMPANY
# Item 24:
# WE SENT CHECK TO: ABC HOSPITAL - A
# Item 25:
# 6
# Item 26:
# ...
